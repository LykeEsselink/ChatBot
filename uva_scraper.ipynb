# %%
import urllib.request as urllib
#import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup

# %%
def read_in_page(url):
    #Query the website and return the html to the variable 'page'
    page = urllib.urlopen(url)
    soup = BeautifulSoup(page)
    return(soup)

# %%
#specify the url
url = "http://student.uva.nl/opleidingen/opleidingenlijst.html?"
main_page = read_in_page(url)
print(main_page.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 8 ]><html lang="nl" class="no-js ie7"><![endif]-->
# <!--[if IE 8 ]><html lang="nl" class="no-js ie8"><![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="nl">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Opleidingen - UvA Studenten - Universiteit van Amsterdam
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="//student.uva.nl/webfiles/1528455820524/css/style.css" rel="stylesheet" type="text/css"/>
#   <link href="http://student.uva.nl/opleidingen/opleidingenlijst.html" rel="canonical"/>
#   <meta content="Opleidingen - UvA Studenten - Universiteit van Amsterdam" property="og:title"/>
#   <meta content="06-06-2016" property="article:published_time"/>
#   <meta content="Opleidingen" name="description"/>
#   <meta content="Opleidingen" property="og:description"/>
#   <meta content="nl" http-equiv="content-language"/>
#   <meta content="Universiteit van Amsterdam" name="copyright"/>
#   <meta content="Universiteit van Amsterdam" name="author"/>
#   <meta content="nl" name="language"/>
#   <link href="//student.uva.nl/webfiles/1528455820524/css/subsite/uva.css" rel="stylesheet"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/webfiles/1528455820524/_favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/webfiles/1528455820524/_favicon/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/webfiles/1528455820524/_favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/webfiles/1528455820524/_favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/webfiles/1528455820524/_favicon/manifest.json" rel="manifest"/>
#   <link color="#000000" href="/webfiles/1528455820524/_favicon/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="/webfiles/1528455820524/favicon.ico" rel="shortcut icon"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="/webfiles/1528455820524/_favicon/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <!--[if IE ]>
#         <link rel="stylesheet"
#               href="http://student.uva.nl/webfiles/1528455820524/css/ie.css" />
#         <![endif]-->
#   <script type="text/javascript">
#    var hpCookie="HPRedirectInit";
#             function getCookie(name){
#                 var parts=("; "+document.cookie).split("; "+name+"=");
#                 if(parts.length==2)return parts.pop().split(";").shift();
#             }
#             if(!getCookie(hpCookie)){
#                 document.cookie=hpCookie+"=1; domain=www.uva.nl; path=/";
#                 if(!navigator.languages){navigator.languages=[navigator.language];}
#                 var pl='en';
#                 for (var i=0;i<navigator.languages.length;i++) {
#                     var l=navigator.languages[i].split('-').shift();
#                     if(/en|nl/i.test(l)){pl=l;break;}
#                 }
#
#             }
#   </script>
#   <script src="//student.uva.nl/webfiles/1528455820524/js/lib/modernizr-2.8.3.min.js" type="text/javascript">
#   </script>
#   <script>
#    var require = {
#
#                 deps: [
#                     "jquery-ui", "lib/typeahead"
#                 ],
#                 shim: {
#                     "jquery-ui": ['jquery'],
#                     "jquery-validation": ['jquery', 'jquery-ui'],
#                     "mathjax": {
#                         exports: "MathJax",
#                         init: function () {
#                             MathJax.Hub.Config({
#                                 "HTML-CSS": { linebreaks: { automatic: true, width: "100%  container" } }
#                             });
#                             MathJax.Hub.Startup.onload();
#                             return MathJax;
#                         }
#                     }
#                 },
#                 // alias mappings
#                 paths: {
#                     "jquery": "//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min",
#                     "jquery-ui": "//ajax.googleapis.com/ajax/libs/jqueryui/1.11.1/jquery-ui.min",
#                     "jquery-validation": "//ajax.aspnetcdn.com/ajax/jquery.validate/1.13.0/jquery.validate.min",
#                     "mathjax": "//cdn.mathjax.org/mathjax/latest/MathJax.js?config=TeX-AMS_HTML&amp;delayStartupUntil=configured"
#                 }
#             };
# 			var restapi = '//www.uva.nl/_restapi';
#   </script>
#   <script data-main="/webfiles/1528455820524/js/main.js" src="//student.uva.nl/webfiles/1528455820524/js/lib/require-2.1.20.min.js">
#   </script>
#   <!--dataLayer-->
#   <script>
#    dataLayer = [
#                 {
#                     'canonicalHostName': 'student.uva.nl',
#                     'canonicalURI': '/opleidingen/opleidingenlijst.html',
#                     'visitorLoginState': 'anonymous'
#                 }
#             ];
#   </script>
#   <!--END dataLayer-->
#  </head>
#  <body class=" students-home " id="defaultpage-extended" site-root="http://student.uva.nl/">
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-HX98" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function (w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#         var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src = '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-HX98');
#   </script>
#   <!-- End Google Tag Manager -->
#   <div class="loader">
#   </div>
#   <header>
#    <div class="container clearfix" id="topheader">
#     <div class="eight columns">
#      <h1>
#       <a href="http://www.uva.nl" id="logo">
#        <img alt="" src="//static.uva.nl/binaries/content/gallery/logos/p-z/uva-logo_nl.jpg"/>
#       </a>
#      </h1>
#     </div>
#     <div class="four columns">
#      <div class="inner-spacer">
#      </div>
#     </div>
#     <div class="four columns">
#      <form action="/search" class="" id="search">
#       <div class="search-box">
#        <input autocomplete="off" name="q" placeholder="Zoek..." type="search" value=""/>
#        <input type="submit" value="Zoek"/>
#       </div>
#      </form>
#     </div>
#    </div>
#    <nav class="container clearfix" id="topheadernav">
#     <div class="sixteen columns">
#      <ul>
#       <li>
#        <a href="http://www.uva.nl/onderwijs">
#         Studiekiezers
#        </a>
#       </li>
#       <li>
#        <a href="http://alumni.uva.nl">
#         Alumni
#        </a>
#       </li>
#       <li>
#        <a href="http://www.student.uva.nl/en">
#         English
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#    <nav class="clearfix" id="megadropdown">
#     <div class="container">
#      <ul class="sixteen columns megalist">
#       <li>
#        <a class="back" href="http://www.uva.nl">
#         UvA Homepage
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#   </header>
#   <div class="clearfix" id="main" role="main">
#    <div class="background clearfix" style="background-image: url('/binaries/sectionbanner/content/gallery/faculteiten-en-diensten/uva-bureau-communicatie/homepage-carrousel/2013/oudemanhuispoort-fotodirkgillissen-studentensite-hp-img_6043.jpg')">
#     <nav id="breadcrumb">
#      <div class="container clearfix">
#       <ul>
#        <li>
#         <a href="/">
#          Home
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <header class="container" id="subheader">
#      <div class="columns sixteen">
#       <div class="inner-spacer">
#        <h1>
#         UvA Studenten
#        </h1>
#        <form action="/opleidingen/opleidingenlijst.html" class="search-box with-label" method="get" novalidate="novalidate">
#         <label style="cursor:auto;">
#          <span>
#           Zoek je opleiding
#          </span>
#         </label>
#         <input autocomplete="off" name="search" placeholder="Zoek..." type="search" value=""/>
#         <input type="submit" value="Zoek"/>
#        </form>
#        <ul class="linklist">
#         <li>
#          <a class="" href="/opleidingen/opleidingenlijst.html">
#           Alle opleidingen
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </header>
#    </div>
#    <div>
#     <div>
#      <div>
#       <div>
#        <div class="container equal-height layout-1-3 clearfix">
#         <aside class="four columns">
#          <div class="inner-spacer">
#           <div class="mobile-move-to-article">
#            <h3>
#             Filter op:
#            </h3>
#            <div class="filter-group show-on-mobile">
#             <form class="search-box" method="get">
#              <input class="form-control" name="search" placeholder="Zoek..." type="search" value=""/>
#              <input class="search-button" type="submit" value="Zoek"/>
#             </form>
#            </div>
#            <hr/>
#            <h4>
#             Programmatype
#            </h4>
#            <ul class="filter">
#             <li>
#              <a href="?t=bachelor">
#               Bachelor
#               <span class="meta">
#                (73)
#               </span>
#              </a>
#             </li>
#             <li>
#              <a href="?t=master">
#               Master
#               <span class="meta">
#                (124)
#               </span>
#              </a>
#             </li>
#             <li>
#              <a href="?t=research-master">
#               Research master
#               <span class="meta">
#                (20)
#               </span>
#              </a>
#             </li>
#            </ul>
#            <hr/>
#            <h4>
#             Faculteit
#            </h4>
#            <ul class="filter">
#             <li>
#              <a href="?t=feb">
#               Economie en Bedrijfskunde
#               <span class="meta">
#                (16)
#               </span>
#              </a>
#             </li>
#             <li>
#              <a href="?t=fgw">
#               Geesteswetenschappen
#               <span class="meta">
#                (108)
#               </span>
#              </a>
#             </li>
#             <li>
#              <a href="?t=medicine">
#               Geneeskunde
#               <span class="meta">
#                (4)
#               </span>
#              </a>
#             </li>
#             <li>
#              <a href="?t=fmg">
#               Maatschappij- en Gedragswetenschappen
#               <span class="meta">
#                (34)
#               </span>
#              </a>
#             </li>
#             <li>
#              <a href="?t=fnwi">
#               Natuurwetenschappen, Wiskunde en Informatica
#               <span class="meta">
#                (30)
#               </span>
#              </a>
#             </li>
#             <li>
#              <a href="?t=fdr">
#               Rechtsgeleerdheid
#               <span class="meta">
#                (26)
#               </span>
#              </a>
#             </li>
#             <li>
#              <a href="?t=dentistry">
#               Tandheelkunde
#               <span class="meta">
#                (2)
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </aside>
#         <article class="twelve columns">
#          <div class="inner-spacer">
#           <div class="title-space">
#            <h1>
#             Opleidingen
#            </h1>
#           </div>
#           <div class="toppager clearfix">
#            <p>
#             Resultaten
#             <strong>
#              1
#         - 219
#             </strong>
#             van 219
#            </p>
#           </div>
#           <table class="with-top-border">
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eco">
#               Accountancy and Control (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eco">
#               Actuarial Science and Mathematical Finance (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ecb">
#               Actuariële wetenschappen (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/asw">
#               Algemene sociale wetenschappen (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/law/">
#               Amsterdam EXchange programme - Amsterdam Law School
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ess">
#               Amsterdam Exchange Programme – Social Sciences
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ara">
#               Arabische taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Arbeidsrecht (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Arbeidsrecht: Arbeid en onderneming (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/march">
#               Archaeology: Archaeology of North-Western Europe (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/marc">
#               Archaeology: Heritage, Memory and Archaeology (Research Master’s)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/march">
#               Archaeology: Landscape and Heritage (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/march">
#               Archaeology: Mediterranean Archaeology (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/arc">
#               Archeologie en prehistorie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ai">
#               Artificial Intelligence (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mac">
#               Arts and Culture: Art Studies (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mac">
#               Arts and Culture: Artistic Research (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mac">
#               Arts and Culture: Arts of the Netherlands (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mac">
#               Arts and Culture: Comparative Cultural Analysis (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mac">
#               Arts and Culture: Cultural Analysis (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mindra">
#               Arts and Culture: International Dramaturgy (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mac">
#               Arts and Culture: Musicology (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mac">
#               Arts and Culture: Theatre Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/phys-astro">
#               Astronomy and Astrophysics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bg">
#               Bèta-gamma (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mbed">
#               Bijzondere educatieve master Duits (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bs">
#               Biological Sciences (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bio">
#               Biologie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bmed">
#               Biomedical Sciences (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bw">
#               Biomedische wetenschappen (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bcs">
#               Brain and Cognitive Sciences (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/eco">
#               Business Administration (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eco">
#               Business Administration (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eco">
#               Business Economics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/chem">
#               Chemistry (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/rmcde">
#               Child Development and Education (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mcac">
#               Classics and Ancient Civilizations: Ancient History (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mcac">
#               Classics and Ancient Civilizations: Ancient Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mcac">
#               Classics and Ancient Civilizations: Classics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/bclc">
#               Cognition, Language and Communication (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mtec">
#               Communicatie en Informatiewetenschappen: Tekst en communicatie (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bcw">
#               Communicatiewetenschap (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mlog">
#               Communication and Information Studies: Argumentation, Rhetoric and Communication (Research Master’s)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mdas">
#               Communication and Information Studies: Discourse and Argumentation studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/cs">
#               Communication Science (Bachelor's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mcs">
#               Communication Science (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mcs">
#               Communication Science (Research Master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/cls">
#               Computational Science (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mcrg">
#               Conflict Resolution and Governance (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mcons">
#               Conservation and Restoration of Cultural Heritage (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mcas">
#               Contemporary Asian Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mcsa">
#               Cultural and Social Anthropology (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ca">
#               Culturele antropologie en ontwikkelingssociologie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/acw">
#               Cultuurwetenschappen (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/dui">
#               Duitse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/es">
#               Earth Sciences (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eco">
#               Econometrics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ecb">
#               Econometrie en operationeel research (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eco">
#               Economics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eco">
#               Economics and business (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/eco">
#               Economics and Business Economics (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ecb">
#               Economie en Bedrijfskunde (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eng">
#               Engelse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/elac">
#               English Language and Culture (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eco">
#               Entrepreneurship (joint degree VU and UvA)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/rechten">
#               European Private Law (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bes">
#               European Studies (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mes">
#               European Studies: East European Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mes">
#               European Studies: European Policy (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mes">
#               European Studies: Governing Europe (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mes">
#               European Studies: Identity and Integration (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/eur">
#               Europese studies (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mfi">
#               Filosofie: Wijsbegeerte (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mfi">
#               Filosofie: Wijsbegeerte van een bepaald wetenschapsgebied (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten/">
#               Fiscaal recht (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https:/student.uva.nl/rechten">
#               Fiscaal recht: Internationaal en Europees belastingrecht (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Fiscaal recht: Nederlands belastingrecht (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ecb">
#               Fiscale economie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ecb">
#               Fiscale economie (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/fs">
#               Forensic Science (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/fra">
#               Franse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/fps">
#               Future Planet Studies (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/gnk">
#               Geneeskunde (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mgnk">
#               Geneeskunde (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ges">
#               Geschiedenis (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mge">
#               Geschiedenis (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mge">
#               Geschiedenis (onderzoeksmaster)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mge">
#               Geschiedenis: Duitslandstudies (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mge">
#               Geschiedenis: Geschiedenis van de Internationale Betrekkingen (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mge">
#               Geschiedenis: Gouden Eeuw (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mge">
#               Geschiedenis: Militaire geschiedenis (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mge">
#               Geschiedenis: Publieksgeschiedenis (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/glt">
#               Griekse en Latijnse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/heb">
#               Hebreeuwse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mers">
#               Heritage Studies: Archival and Information Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mers">
#               Heritage Studies: Curating Arts and Culture (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mers">
#               Heritage Studies: Heritage and Memory Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mers">
#               Heritage Studies: Museum Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mpap">
#               Heritage Studies: Preservation and Presentation of the Moving Image (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mhis">
#               History: American Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mhis">
#               History: Holocaust and Genocide Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mhg">
#               Human Geography (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/inc">
#               Informatica (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ifk">
#               Informatiekunde (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Informatierecht (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Information Law (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/is">
#               Information Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ilo">
#               Interfacultaire lerarenopleidingen (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/rechten">
#               International and European Law: European Competition Law and Regulation (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https:/student.uva.nl/rechten">
#               International and European Law: European Union Law (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               International and European Law: International Trade and Investment Law (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               International and European Law: Public International Law (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               International Criminal Law (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mids">
#               International Development Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/rmids">
#               International Development Studies (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ita">
#               Italië studies (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mkc">
#               Kunst- en cultuurwetenschappen: Boekwetenschap en handschriftkunde (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mdra">
#               Kunst- en cultuurwetenschappen: Dramaturgie (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mkc">
#               Kunst- en cultuurwetenschappen: Kunst, cultuur en politiek (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mkc">
#               Kunst- en cultuurwetenschappen: Kunstgeschiedenis (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/kun">
#               Kunstgeschiedenis (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ki">
#               Kunstmatige intelligentie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Labour Law: European and International Labour Law (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/lat">
#               Latijnse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.auc.nl/life-at-auc-students/current-students/current-students">
#               Liberal Arts and Sciences (Bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ls">
#               Life Sciences (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/blin">
#               Linguistics (Bachelor's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlin">
#               Linguistics (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlin">
#               Linguistics: General Linguistics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlin">
#               Linguistics: Language and Education (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlin">
#               Linguistics: Language and Society (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/blin">
#               Linguistics: Sign Language Linguistics (Bachelor’s)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlit">
#               Literary Studies (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlit">
#               Literary Studies: Comparative Literature (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlit">
#               Literary Studies: English literature and Culture (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/lca">
#               Literary Studies: Literary and Cultural Analysis (Bachelor's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlit">
#               Literary Studies: Literature and Education (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mlit">
#               Literary Studies: Literature, Culture and Society (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/lit">
#               Literatuurwetenschap (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/log">
#               Logic (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mph">
#               Mathematical Physics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/math">
#               Mathematics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mai">
#               Media and Information (Bachelor's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mc">
#               Media en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ifw">
#               Media en informatie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mmst">
#               Media Studies (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mmst">
#               Media Studies: Film Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mjem">
#               Media Studies: Journalistiek en media (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mmst">
#               Media Studies: New Media and Digital Culture (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mmst">
#               Media Studies: Television and Cross-Media Culture (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mmas">
#               Medical Anthropology and Sociology (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mmi">
#               Medical Informatics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mi">
#               Medische informatiekunde (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mara">
#               Midden-Oostenstudies (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mheb">
#               Middle Eastern Studies: Hebrew and Jewish Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/muz">
#               Muziekwetenschap (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/nsk">
#               Natuurkunde en Sterrenkunde (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ned">
#               Nederlandse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/tlc">
#               Nederlandse taal en cultuur: Taal en Communicatie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mne">
#               Neerlandistiek: Nederlandse letterkunde (onderzoeksmaster)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mne">
#               Neerlandistiek: Nederlandse taal en cultuur (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mred">
#               Neerlandistiek: Redacteur/editor (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ngr">
#               Nieuwgriekse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
# ...
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Privaatrecht: Commerciële rechtspraktijk (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Privaatrecht: Privaatrechtelijke rechtspraktijk (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/pb">
#               Psychobiologie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/psy">
#               Psychologie (bachelor en master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/rmp">
#               Psychology (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Public International Law (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Publiekrecht: Gezondheidsrecht (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Publiekrecht: Militair recht (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Publiekrecht: Staats- en bestuursrecht (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten">
#               Publiekrecht: Strafrecht (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="https://student.uva.nl/rechten/">
#               Rechtsgeleerdheid (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/rel">
#               Religiewetenschappen (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/sca">
#               Scandinavische talen en culturen (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/sck">
#               Scheikunde (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/sla">
#               Slavische talen en culturen (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/rmss">
#               Social Sciences (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/sgpl">
#               Sociale geografie en Planologie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/soc">
#               Sociologie (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/bsoc">
#               Sociology (Bachelor's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/msoc">
#               Sociology (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/se">
#               Software Engineering (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/spa">
#               Spaanse taal en cultuur (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/sfm">
#               Stochastics and Financial Mathematics (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/sne">
#               System and Network Engineering (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/atw">
#               Taalwetenschap (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/ngt">
#               Taalwetenschap: Gebarentaalwetenschap (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mntt">
#               Taalwetenschappen: Nederlands als tweede taal en meertaligheid (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/mtwv">
#               Taalwetenschappen: Vertalen (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/opleidingen/tandheelkunde">
#               Tandheelkunde (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/opleidingen/tandheelkunde">
#               Tandheelkunde (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/thw">
#               Theaterwetenschap (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mtr">
#               Theologie en religiewetenschappen: Islam in de moderne wereld (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mtr">
#               Theologie en religiewetenschappen: Religie en identiteit in de moderne wereld (master)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mtrs">
#               Theology and Religious Studies: Religious Studies (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mtrs">
#               Theology and Religious Studies: Religious Studies (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://student.uva.nl/mtrs">
#               Theology and Religious Studies: Western Esotericism (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/upva">
#               Universitaire Pabo van Amsterdam
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/murp">
#               Urban and Regional Planning (Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/rmus">
#               Urban Studies (Research Master's)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/wys">
#               Wijsbegeerte (bachelor)
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <a class="icon-arrow" href="http://www.student.uva.nl/wis">
#               Wiskunde (bachelor)
#              </a>
#             </td>
#            </tr>
#           </table>
#          </div>
#         </article>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container clearfix equal-height">
#     <div class="sixteen columns">
#      <div class="quicknav">
#       <h4>
#        Direct naar
#       </h4>
#       <nav>
#        <a href="https://blackboard.uva.nl">
#         <span class="icon-64 blackboard">
#         </span>
#         <span>
#          Blackboard
#         </span>
#        </a>
#        <a href="http://www.student.uva.nl/sis">
#         <span class="icon-64 sis">
#         </span>
#         <span>
#          SIS / Cijfers
#         </span>
#        </a>
#        <a href="http://student.uva.nl/content/az/uva-apps/uva-apps.html?origin=84HxqDR7R5ivoe2fREDZiw">
#         <span class="icon-64 my-uva">
#         </span>
#         <span>
#          MijnUvA app
#         </span>
#        </a>
#        <a href="http://uvadatamonitor.uva.nl/">
#         <span class="icon-64 registration-of-marks">
#         </span>
#         <span>
#          UvAdata Monitors
#         </span>
#         <span class="tooltip">
#          <span class="title">
#           UvAdata Monitors
#          </span>
#          <span class="description">
#           Alle feiten en cijfers over de Universiteit van Amsterdam
#          </span>
#         </span>
#        </a>
#        <a href="http://email.student.uva.nl">
#         <span class="icon-64 web-mail">
#         </span>
#         <span>
#          Webmail
#         </span>
#        </a>
#        <a href="http://uba.uva.nl">
#         <span class="icon-64 library">
#         </span>
#         <span>
#          Bibliotheek
#         </span>
#        </a>
#        <a href="http://rooster.uva.nl">
#         <span class="icon-64 schedule">
#         </span>
#         <span>
#          Roosters
#         </span>
#        </a>
#        <a href="http://studiegids.uva.nl/xmlpages/page/2018-2019">
#         <span class="icon-64 guide">
#         </span>
#         <span>
#          Studiegids
#         </span>
#        </a>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container equal-height clearfix">
#    <div class="sixteen columns">
#     <div class="inner-spacer" id="social-strip">
#      <span class="text-share">
#       Delen
#      </span>
#      <a class="icon icon-send_groen" href="mailto:?body=http%3A%2F%2Fstudent.uva.nl%2Fopleidingen%2Fopleidingenlijst.html&amp;subject=Opleidingen%20-%20UvA%20Studenten%20-%20Universiteit%20van%20Amsterdam">
#       <span class="visuallyhidden">
#        Delen via email
#       </span>
#      </a>
#      <a class="icon icon-facebook_blauw" href="http://www.facebook.com/sharer.php?u=http%3A%2F%2Fstudent.uva.nl%2Fopleidingen%2Fopleidingenlijst.html" target="_blank">
#       <span class="visuallyhidden">
#        Delen op facebook
#       </span>
#      </a>
#      <a class="icon icon-linkedin_blauw" href="http://www.linkedin.com/shareArticle?mini=true&amp;url=http%3A%2F%2Fstudent.uva.nl%2Fopleidingen%2Fopleidingenlijst.html" target="_blank">
#       <span class="visuallyhidden">
#        Delen op linkedin
#       </span>
#      </a>
#      <a class="icon icon-twitter_blauw" href="http://twitter.com/share?url=http%3A%2F%2Fstudent.uva.nl%2Fopleidingen%2Fopleidingenlijst.html&amp;text=Opleidingen%20-%20UvA%20Studenten%20-%20Universiteit%20van%20Amsterdam" target="_blank">
#       <span class="visuallyhidden">
#        Delen op twitter
#       </span>
#      </a>
#      <a class="icon icon-googleplus_oranje" href="https://plus.google.com/share?url=http%3A%2F%2Fstudent.uva.nl%2Fopleidingen%2Fopleidingenlijst.html" target="_blank">
#       <span class="visuallyhidden">
#        Delen via Google+
#       </span>
#      </a>
#      <span class="text-print">
#       Print
#      </span>
#      <a class="icon icon-print_groenblauw" href="javascript:print()" title="Print deze pagina">
#       <span class="visuallyhidden">
#        Print deze pagina
#       </span>
#      </a>
#     </div>
#    </div>
#   </div>
#   <footer>
#    <div class="container clearfix">
#     <div class="four columns">
#      <div class="inner-spacer">
#       <ul class="linklist">
#       </ul>
#      </div>
#     </div>
#     <div class="four columns">
#      <div class="inner-spacer">
#       <ul class="linklist">
#       </ul>
#      </div>
#     </div>
#     <div class="four columns">
#      <div class="inner-spacer">
#       <ul class="linklist">
#        <li>
#         <a href="http://www.student.uva.nl/ssd">
#          Contact
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="four columns">
#      <div class="inner-spacer">
#       <ul class="linklist">
#        <li>
#         <a class="list-icon icon-facebook_blauw" href="https://www.facebook.com/UniversityofAmsterdam">
#          Volg de UvA op Facebook
#         </a>
#        </li>
#        <li>
#         <a class="list-icon icon-twitter_blauw" href="https://twitter.com/UvA_Student">
#          Stel je vraag op Twitter
#         </a>
#        </li>
#        <li>
#         <a class="list-icon icon-instagram_bruin" href="http://www.instagram.com/uva_amsterdam">
#          De UvA op Instagram
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="container clearfix">
#     <div class="sixteen columns" id="copyright">
#      <div class="inner-spacer">
#       <span style="margin-right: 15px;">
#        Copyright UvA 2018
#       </span>
#       <a href="http://www.uva.nl/home/disclaimers/disclaimer">
#        Disclaimer
#       </a>
#       <a href="http://www.uva.nl/home/disclaimers/cookies">
#        Cookies
#       </a>
#       <a href="http://www.uva.nl/home/disclaimers/privacy">
#        Privacy
#       </a>
#       <span class="toggle-mobile">
#        <span class="show-mobile">
#         Mobiele weergave
#        </span>
#        <span class="show-desktop">
#         Desktopversie
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div id="cookie-bar">
#    <div class="container clearfix">
#     <div class="columns eight">
#      <div class="inner-spacer">
#       De websites van de UvA maken gebruik van cookies.
#      </div>
#     </div>
#     <div class="columns four">
#      <div class="inner-spacer">
#       <a class="close" href="#">
#        Deze melding verbergen
#       </a>
#      </div>
#     </div>
#     <div class="columns four">
#      <div class="inner-spacer">
#       <a class="right-align" href="http://www.uva.nl/home/disclaimers/cookies">
#        Meer informatie
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--[if lt IE 7 ]>
# <script src="//ajax.googleapis.com/ajax/libs/chrome-frame/1/CFInstall.min.js"></script>
# <script>window.attachEvent('onload',function(){CFInstall.check({mode:'overlay'})})</script>
# <![endif]-->
#  </body>
# </html>
# /Users/Iris/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/Iris/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
def get_links(page):
    links = page.find_all("a", class_="icon-arrow")
    links_new = []
    for link in links:
        sep = '?'
        rest = link['href'].split(sep, 1)[0]
        links_new.append(rest)
    return(links_new)
    
program_links = get_links(main_page)

program_links
# Out:
# ['http://www.student.uva.nl/eco',
#  'http://www.student.uva.nl/eco',
#  'http://www.student.uva.nl/ecb',
#  'http://www.student.uva.nl/asw',
#  'https://student.uva.nl/law/',
#  'http://www.student.uva.nl/ess',
#  'http://www.student.uva.nl/ara',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'http://student.uva.nl/march',
#  'http://www.student.uva.nl/marc',
#  'http://student.uva.nl/march',
#  'http://student.uva.nl/march',
#  'http://www.student.uva.nl/arc',
#  'http://www.student.uva.nl/ai',
#  'http://student.uva.nl/mac',
#  'http://student.uva.nl/mac',
#  'http://student.uva.nl/mac',
#  'http://student.uva.nl/mac',
#  'http://student.uva.nl/mac',
#  'http://student.uva.nl/mindra',
#  'http://student.uva.nl/mac',
#  'http://student.uva.nl/mac',
#  'http://www.student.uva.nl/phys-astro',
#  'http://www.student.uva.nl/bg',
#  'http://student.uva.nl/mbed',
#  'http://www.student.uva.nl/bs',
#  'http://www.student.uva.nl/bio',
#  'http://www.student.uva.nl/bmed',
#  'http://www.student.uva.nl/bw',
#  'http://www.student.uva.nl/bcs',
#  'http://student.uva.nl/eco',
#  'http://www.student.uva.nl/eco',
#  'http://www.student.uva.nl/eco',
#  'http://www.student.uva.nl/chem',
#  'http://www.student.uva.nl/rmcde',
#  'http://student.uva.nl/mcac',
#  'http://student.uva.nl/mcac',
#  'http://student.uva.nl/mcac',
#  'http://student.uva.nl/bclc',
#  'http://www.student.uva.nl/mtec',
#  'http://www.student.uva.nl/bcw',
#  'http://www.student.uva.nl/mlog',
#  'http://www.student.uva.nl/mdas',
#  'http://student.uva.nl/cs',
#  'http://www.student.uva.nl/mcs',
#  'http://student.uva.nl/mcs',
#  'http://www.student.uva.nl/cls',
#  'http://www.student.uva.nl/mcrg',
#  'http://www.student.uva.nl/mcons',
#  'http://www.student.uva.nl/mcas',
#  'http://www.student.uva.nl/mcsa',
#  'http://www.student.uva.nl/ca',
#  'http://www.student.uva.nl/acw',
#  'http://www.student.uva.nl/dui',
#  'http://www.student.uva.nl/es',
#  'http://www.student.uva.nl/eco',
#  'http://www.student.uva.nl/ecb',
#  'http://www.student.uva.nl/eco',
#  'http://www.student.uva.nl/eco',
#  'http://student.uva.nl/eco',
#  'http://www.student.uva.nl/ecb',
#  'http://www.student.uva.nl/eng',
#  'http://student.uva.nl/elac',
#  'http://www.student.uva.nl/eco',
#  'http://www.student.uva.nl/rechten',
#  'http://www.student.uva.nl/bes',
#  'http://student.uva.nl/mes',
#  'http://student.uva.nl/mes',
#  'http://student.uva.nl/mes',
#  'http://student.uva.nl/mes',
#  'http://www.student.uva.nl/eur',
#  'http://student.uva.nl/mfi',
#  'http://student.uva.nl/mfi',
#  'https://student.uva.nl/rechten/',
#  'https:/student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'http://www.student.uva.nl/ecb',
#  'http://www.student.uva.nl/ecb',
#  'http://www.student.uva.nl/fs',
#  'http://www.student.uva.nl/fra',
#  'http://www.student.uva.nl/fps',
#  'http://student.uva.nl/gnk',
#  'http://student.uva.nl/mgnk',
#  'http://www.student.uva.nl/ges',
#  'http://student.uva.nl/mge',
#  'http://student.uva.nl/mge',
#  'http://student.uva.nl/mge',
#  'http://student.uva.nl/mge',
#  'http://student.uva.nl/mge',
#  'http://student.uva.nl/mge',
#  'http://student.uva.nl/mge',
#  'http://www.student.uva.nl/glt',
#  'http://www.student.uva.nl/heb',
#  'http://www.student.uva.nl/mers',
#  'http://www.student.uva.nl/mers',
#  'http://www.student.uva.nl/mers',
#  'http://www.student.uva.nl/mers',
#  'http://www.student.uva.nl/mpap',
#  'http://student.uva.nl/mhis',
#  'http://student.uva.nl/mhis',
#  'http://www.student.uva.nl/mhg',
#  'http://www.student.uva.nl/inc',
#  'http://www.student.uva.nl/ifk',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'http://www.student.uva.nl/is',
#  'http://www.student.uva.nl/ilo',
#  'http://www.student.uva.nl/rechten',
#  'https:/student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'http://www.student.uva.nl/mids',
#  'http://www.student.uva.nl/rmids',
#  'http://www.student.uva.nl/ita',
#  'http://student.uva.nl/mkc',
#  'http://www.student.uva.nl/mdra',
#  'http://student.uva.nl/mkc',
#  'http://student.uva.nl/mkc',
#  'http://www.student.uva.nl/kun',
#  'http://www.student.uva.nl/ki',
#  'https://student.uva.nl/rechten',
#  'http://www.student.uva.nl/lat',
#  'http://www.auc.nl/life-at-auc-students/current-students/current-students',
#  'http://www.student.uva.nl/ls',
#  'http://student.uva.nl/blin',
#  'http://student.uva.nl/mlin',
#  'http://student.uva.nl/mlin',
#  'http://student.uva.nl/mlin',
#  'http://student.uva.nl/mlin',
#  'http://student.uva.nl/blin',
#  'http://student.uva.nl/mlit',
#  'http://student.uva.nl/mlit',
#  'http://student.uva.nl/mlit',
#  'http://student.uva.nl/lca',
#  'http://student.uva.nl/mlit',
#  'http://student.uva.nl/mlit',
#  'http://www.student.uva.nl/lit',
#  'http://www.student.uva.nl/log',
#  'http://www.student.uva.nl/mph',
#  'http://www.student.uva.nl/math',
#  'http://student.uva.nl/mai',
#  'http://www.student.uva.nl/mc',
#  'http://www.student.uva.nl/ifw',
#  'http://student.uva.nl/mmst',
#  'http://student.uva.nl/mmst',
#  'http://www.student.uva.nl/mjem',
#  'http://student.uva.nl/mmst',
#  'http://student.uva.nl/mmst',
#  'http://www.student.uva.nl/mmas',
#  'http://student.uva.nl/mmi',
#  'http://student.uva.nl/mi',
#  'http://www.student.uva.nl/mara',
#  'http://student.uva.nl/mheb',
#  'http://www.student.uva.nl/muz',
#  'http://www.student.uva.nl/nsk',
#  'http://www.student.uva.nl/ned',
#  'http://www.student.uva.nl/tlc',
#  'http://student.uva.nl/mne',
#  'http://student.uva.nl/mne',
#  'http://www.student.uva.nl/mred',
#  'http://www.student.uva.nl/ngr',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'http://www.student.uva.nl/mow',
#  'http://student.uva.nl/bohw',
#  'http://www.student.uva.nl/pow',
#  'http://www.student.uva.nl/mpw',
#  'http://student.uva.nl/mphi',
#  'http://student.uva.nl/mphi',
#  'http://www.student.uva.nl/phys-astro',
#  'http://www.student.uva.nl/phys-astro',
#  'http://www.student.uva.nl/polsc',
#  'http://www.student.uva.nl/mpol',
#  'http://www.student.uva.nl/pol',
#  'http://www.student.uva.nl/mpol',
#  'http://www.student.uva.nl/pple',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'http://www.student.uva.nl/pb',
#  'http://www.student.uva.nl/psy',
#  'http://www.student.uva.nl/rmp',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten',
#  'https://student.uva.nl/rechten/',
#  'http://www.student.uva.nl/rel',
#  'http://www.student.uva.nl/sca',
#  'http://www.student.uva.nl/sck',
#  'http://www.student.uva.nl/sla',
#  'http://www.student.uva.nl/rmss',
#  'http://www.student.uva.nl/sgpl',
#  'http://www.student.uva.nl/soc',
#  'http://www.student.uva.nl/bsoc',
#  'http://www.student.uva.nl/msoc',
#  'http://www.student.uva.nl/se',
#  'http://www.student.uva.nl/spa',
#  'http://www.student.uva.nl/sfm',
#  'http://www.student.uva.nl/sne',
#  'http://www.student.uva.nl/atw',
#  'http://www.student.uva.nl/ngt',
#  'http://www.student.uva.nl/mntt',
#  'http://www.student.uva.nl/mtwv',
#  'http://student.uva.nl/opleidingen/tandheelkunde',
#  'http://student.uva.nl/opleidingen/tandheelkunde',
#  'http://www.student.uva.nl/thw',
#  'http://student.uva.nl/mtr',
#  'http://student.uva.nl/mtr',
#  'http://student.uva.nl/mtrs',
#  'http://student.uva.nl/mtrs',
#  'http://student.uva.nl/mtrs',
#  'http://www.student.uva.nl/upva',
#  'http://www.student.uva.nl/murp',
#  'http://www.student.uva.nl/rmus',
#  'http://www.student.uva.nl/wys',
#  'http://www.student.uva.nl/wis']

# %%
url = program_links[0]
az_url = url + "/az"
print(az_url)
# Out:
# http://www.student.uva.nl/eco/az

# %%
az_page = read_in_page(az_url)
az_links = get_links(az_page)
az_links_new = []
for link in az_links:
        link = "http://www.student.uva.nl" + link
        az_links_new.append(link)
print(az_links_new)
# Out:
# ['http://www.student.uva.nl/eco/content/az/academic-calendar/academic-calendar.html', 'http://www.student.uva.nl/eco/content/az/accreditations---feb/accreditiations.html', 'http://www.student.uva.nl/eco/content/az/statement-of-admission-to-master/enrolment-faculty-of-economics-and-business---masters.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/bicycle-parking/bicycle-parking.html', 'http://www.student.uva.nl/eco/content/az/binding-study-advice-bsa/binding-study-advice-bsa.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/blackboard/blackboard.html', 'http://www.student.uva.nl/eco/content/az/board-of-examiners/board-of-examiners.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/career/career.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/change-of-address-notification/change-of-address-notification.html', 'http://www.student.uva.nl/eco/content/az/changing-programmes-or-specialisations/changing-programmes-or-specializations.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/clean-study-and-work-environment/clean-study-and-work-environment.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/complaints-objections-and-appeals/complaints-objections-and-appeals.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/confidential-adviser-for-undesirable-behaviour/confidential-adviser-for-undesirable-behaviour.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/contemplation-rooms/contemplation-rooms.html', 'http://www.student.uva.nl/eco/content/az/course-and-exam-registration-feb/course-and-exam-registration.html', 'http://www.student.uva.nl/eco/content/az/optional-courses-at-uva-economics-and-business/optional-courses-at-uva-economics-and-business.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/cultural-organisation-crea/cultural-organisation-crea.html', 'http://www.student.uva.nl/eco/content/az/cum-laude/cum-laude.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/data-storage/data-storage.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/dentists/dentists.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/disability-or-chronic-illness/disability-or-chronic-illness.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/doctors/doctors.html', 'http://www.student.uva.nl/eco/content/az/dutch-language-course/dutch-language-course.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/dutch-study-grant-system/dutch-student-loan-system.html', 'http://www.student.uva.nl/eco/content/az/dyslexia---feb/dyslexia-feb.html', 'http://www.student.uva.nl/eco/content/az/electives/electives.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/student-email/student-email.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/emergencies-and-first-aid/emergencies-and-first-aid.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/entrepreneurship/entrepreneurship.html', 'http://www.student.uva.nl/eco/content/az/exams-and-resits/exams-and-resits.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/expense-claims-and-advances/expense-claims-and-advances.html', 'http://www.student.uva.nl/eco/content/az/extra-resit/extra-resit-faq.html', 'http://www.student.uva.nl/eco/content/az/faculty-student-council-fsr-feb/faculty-student-council-fsr-feb.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/flexible-learning/flexible-learning.html', 'http://www.student.uva.nl/eco/shared/studentensites/uva-studentensite/en/az/food-and-drink/food-and-drinks-at-the-uva. ...
# /Users/Iris/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/Iris/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
az_page_html = read_in_page(az_links_new[0])
print(az_page_html.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 8 ]><html lang="en" class="no-js ie7"><![endif]-->
# <!--[if IE 8 ]><html lang="en" class="no-js ie8"><![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Academic calendar - Students Economics and Business - University of Amsterdam
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="//student.uva.nl/webfiles/1528455820524/css/style.css" rel="stylesheet" type="text/css"/>
#   <!--[if gt IE 8]><!-->
#   <link href="//student.uva.nl/webfiles/1528455820524/css/mobile.css" rel="stylesheet" type="text/css"/>
#   <!--<![endif]-->
#   <link href="http://student.uva.nl/eco/content/az/academic-calendar/academic-calendar.html" rel="canonical"/>
#   <meta content="Academic calendar - Students Economics and Business - University of Amsterdam" property="og:title"/>
#   <meta content="12-01-2018" property="article:published_time"/>
#   <meta content="The academic calendar for UvA Economics and Business is published in three documents." name="description"/>
#   <meta content="The academic calendar for UvA Economics and Business is published in three documents." name="og:description"/>
#   <meta content="en" http-equiv="content-language"/>
#   <meta content="Universiteit van Amsterdam" name="copyright"/>
#   <meta content="Universiteit van Amsterdam" name="author"/>
#   <meta content="en" name="language"/>
#   <link href="//student.uva.nl/webfiles/1528455820524/css/subsite/uva.css" rel="stylesheet"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/webfiles/1528455820524/_favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/webfiles/1528455820524/_favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/webfiles/1528455820524/_favicon/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/webfiles/1528455820524/_favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/webfiles/1528455820524/_favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/webfiles/1528455820524/_favicon/manifest.json" rel="manifest"/>
#   <link color="#000000" href="/webfiles/1528455820524/_favicon/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="/webfiles/1528455820524/favicon.ico" rel="shortcut icon"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="/webfiles/1528455820524/_favicon/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <!--[if IE ]>
#         <link rel="stylesheet"
#               href="http://student.uva.nl/webfiles/1528455820524/css/ie.css" />
#         <![endif]-->
#   <script type="text/javascript">
#    var hpCookie="HPRedirectInit";
#             function getCookie(name){
#                 var parts=("; "+document.cookie).split("; "+name+"=");
#                 if(parts.length==2)return parts.pop().split(";").shift();
#             }
#             if(!getCookie(hpCookie)){
#                 document.cookie=hpCookie+"=1; domain=www.uva.nl; path=/";
#                 if(!navigator.languages){navigator.languages=[navigator.language];}
#                 var pl='en';
#                 for (var i=0;i<navigator.languages.length;i++) {
#                     var l=navigator.languages[i].split('-').shift();
#                     if(/en|nl/i.test(l)){pl=l;break;}
#                 }
#
#             }
#   </script>
#   <script src="//student.uva.nl/webfiles/1528455820524/js/lib/modernizr-2.8.3.min.js" type="text/javascript">
#   </script>
#   <script>
#    var require = {
#
#                 deps: [
#                     "jquery-ui", "lib/typeahead"
#                 ],
#                 shim: {
#                     "jquery-ui": ['jquery'],
#                     "jquery-validation": ['jquery', 'jquery-ui'],
#                     "mathjax": {
#                         exports: "MathJax",
#                         init: function () {
#                             MathJax.Hub.Config({
#                                 "HTML-CSS": { linebreaks: { automatic: true, width: "100%  container" } }
#                             });
#                             MathJax.Hub.Startup.onload();
#                             return MathJax;
#                         }
#                     }
#                 },
#                 // alias mappings
#                 paths: {
#                     "jquery": "//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min",
#                     "jquery-ui": "//ajax.googleapis.com/ajax/libs/jqueryui/1.11.1/jquery-ui.min",
#                     "jquery-validation": "//ajax.aspnetcdn.com/ajax/jquery.validate/1.13.0/jquery.validate.min",
#                     "mathjax": "//cdn.mathjax.org/mathjax/latest/MathJax.js?config=TeX-AMS_HTML&amp;delayStartupUntil=configured"
#                 }
#             };
# 			var restapi = '//www.uva.nl/_restapi';
#   </script>
#   <script data-main="/webfiles/1528455820524/js/main.js" src="//student.uva.nl/webfiles/1528455820524/js/lib/require-2.1.20.min.js">
#   </script>
#   <!--dataLayer-->
#   <script>
#    dataLayer = [
#                 {
#                     'canonicalHostName': 'student.uva.nl',
#                     'canonicalURI': '/eco/content/az/academic-calendar/academic-calendar.html',
#                     'keywords': 'calendar,education,business,economics and business,year calendar,enrolment periods,enrollment,master's programmes,economics,enrolment,enrolment period,courses, exams and grades,bachelor's programmes,academic calendar,academic year',
#                     'visitorLoginState': 'anonymous'
#                 }
#             ];
#   </script>
#   <!--END dataLayer-->
#   <meta content="calendar,education,business,economics and business,year calendar,enrolment periods,enrollment,master's programmes,economics,enrolment,enrolment period,courses, exams and grades,bachelor's programmes,academic calendar,academic year" name="keywords"/>
#  </head>
#  <body class=" " id="defaultpage-extended" site-root="http://student.uva.nl/eco">
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-HX98" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function (w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#         var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src = '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-HX98');
#   </script>
#   <!-- End Google Tag Manager -->
#   <div class="loader">
#   </div>
#   <script data-home="Students Economics and Business" data-logosrc="/webfiles/1528455820524/gfx/mobile/logo.png" data-logotext="UvA Home" id="mobiletopmenu" type="text/html">
#    <div><a href="/ecb">NL</a></div>
#         <div>
#             <div tabindex="1" class='share'>Share this</div>
#             <div class="share-popup">
#                 <ul class="linklist">
#                     <li><a class="list-icon icon-email" href="mailto:?body=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html&subject=Academic%20calendar%20-%20Students%20Economics%20and%20Business%20-%20University%20of%20Amsterdam">Share via email</a></li>
#                     <li><a class="list-icon icon-facebook" href="http://www.facebook.com/sharer.php?u=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html">Share on facebook</a></li>
#                     <li><a class="list-icon icon-linkedin" href="http://www.linkedin.com/shareArticle?mini=true&url=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html">Share on linkedin</a></li>
#                     <li><a class="list-icon icon-twitter" href="http://twitter.com/share?url=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html&text=Academic%20calendar%20-%20Students%20Economics%20and%20Business%20-%20University%20of%20Amsterdam">Share on twitter</a></li>
#                 </ul>
#             </div>
#         </div>
#   </script>
#   <header>
#    <div class="container clearfix" id="topheader">
#     <div class="eight columns">
#      <h1>
#       <a href="http://www.uva.nl/en" id="logo">
#        <img alt="" src="//static.uva.nl/binaries/content/gallery/logos/p-z/uva-logo_en.jpg"/>
#       </a>
#      </h1>
#     </div>
#     <div class="four columns">
#      <div class="inner-spacer">
#      </div>
#     </div>
#     <div class="four columns">
#      <form action="/eco/search" class="sections" id="search">
#       <div class="search-box">
#        <input autocomplete="off" name="q" placeholder="Search..." type="search" value=""/>
#        <input type="submit" value="Search"/>
#       </div>
#       <div class="search-popup" tabindex="1">
#        <div class="search-choice">
#         <label>
#          <input checked="" name="type" type="radio" value="subject"/>
#          Subject
#         </label>
#         <label>
#          <input name="type" type="radio" value="employee"/>
#          Employee
#         </label>
#        </div>
#       </div>
#      </form>
#     </div>
#    </div>
#    <nav class="container clearfix" id="topheadernav">
#     <div class="sixteen columns">
#      <ul>
#       <li>
#        <a href="http://www.uva.nl/en/education">
#         Prospective students
#        </a>
#       </li>
#       <li>
#        <a href="http://alumni.uva.nl/en">
#         Alumni
#        </a>
#       </li>
#       <li>
#        <a href="http://www.student.uva.nl/ecb">
#         Nederlands
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#    <nav class="clearfix" id="megadropdown">
#     <div class="container">
#      <ul class="sixteen columns megalist">
#       <li>
#        <a class="back" href="http://student.uva.nl/en">
#         All student sites
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#   </header>
#   <div class="clearfix" id="main" role="main">
#    <div class="background clearfix" style="background-image: url('/binaries/sectionbanner/content/gallery/faculteiten-en-diensten/feb/brievenbus-masters/brievenbus-business-4collegas-tafel.jpg')">
#     <nav id="breadcrumb">
#      <div class="container clearfix">
#       <ul>
#        <li>
#         <a href="/eco">
#          Home
#         </a>
#        </li>
#        <li class="current">
#         <a href="/eco/content/az/academic-calendar/academic-calendar.html">
#          Academic Calendar
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <header class="container" id="subheader">
#      <div class="columns sixteen">
#       <div class="inner-spacer">
#        <h2>
#         Economics and Business
#         <span class="minor">
#          (Bachelors and Masters)
#         </span>
#        </h2>
#        <h4 class="subtitle">
#        </h4>
#        <nav class="clearfix" id="submenu">
#         <ul>
#          <li>
#           <a href="/eco">
#            Home
#           </a>
#          </li>
#          <li>
#           <a href="/eco/announcements">
#            Announcements
#           </a>
#          </li>
#          <li>
#           <a href="/eco/news">
#            News
#           </a>
#          </li>
#          <li>
#           <a href="/eco/events">
#            Events
#           </a>
#          </li>
#          <li>
#           <a href="/eco/az">
#            A-Z
#           </a>
#          </li>
#          <li>
#           <a href="/eco/contact">
#            Contact
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#     </header>
#    </div>
#    <div>
#     <div>
#      <div>
#       <div>
#        <div class="container equal-height layout-1-2-1 clearfix">
#         <aside class="four columns">
#          <div class="inner-spacer">
#           <ul class="linklist">
#            <li>
#             <a class="open" href="/eco/content/az/academic-calendar/academic-calendar.html">
#              Academic Calendar
#             </a>
#            </li>
#           </ul>
#          </div>
#         </aside>
#         <article class="eight columns">
#          <div class="inner-spacer">
#           <h1>
#            Academic calendar
#           </h1>
#           <p class="intro">
#            The UvA Economics and Business academic calendar is published in several documents.
#           </p>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class="" href="/eco/shared/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/nl/az/academische-kalender/feb-academische-kalender.html" target="_self">
#               Nederlandstalige informatie
#              </a>
#             </li>
#            </ul>
#           </div>
#           <p>
#            Even though each year the academic calendars are composed with the utmost care no rights can be derived from it. UvA Economics and Business reserves the right to make changes.
#           </p>
#           <h3>
#            Academic calendar 2017-2018
#           </h3>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-nederlands-sia/academische-jaarkalender/17-18/feb_academic_calendar_2017-2018_bsc_-first_year_business-administration-and-economics-business-economics-fiscal-economics.pdf?3021161876409" target="_self">
#               BSc Business Administration, Economics &amp; Business Economics, and Fiscal Economics : year 1
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-nederlands-sia/academische-jaarkalender/17-18/feb_academic_calendar_2017-2018_bsc_year23_eb_fe_19-05-2017.pdf?3021162076466" target="_self">
#               BSc Economics &amp; Business and Fiscal Economie: year 2 and 3
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-nederlands-sia/academische-jaarkalender/17-18/feb_academic_calendar_2017-2018_bsc_aeo_jaar_-1-aangepast-23-5-2017.pdf?3021162018954" target="_self">
#               BSc Econometrics en Operations Research en Actuarial Science: year 1 (with reservation)
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-nederlands-sia/academische-jaarkalender/17-18/feb_academic_calendar_2017-2018_bsc_aeo_jaar_-2_en_3-aangepast-19-5-2017.pdf?3021162043007" target="_self">
#               BSc Econometrics en Operations Research en Actuarial Science: year 2 and 3
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-nederlands-sia/academische-jaarkalender/17-18/feb_academic_calendar_2017-2018_msc_econometrics_aangepast_28-8-2017.pdf?3021162137581" target="_self">
#               MSc Econometrics
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-nederlands-sia/academische-jaarkalender/17-18/feb_academic_calendar_2017-2018_all_msc_beh_ectrics_aangepast_19-05-2017.pdf?3021161654483" target="_self">
#               Other Master's programmes
#              </a>
#             </li>
#            </ul>
#           </div>
#           <h3>
#            Academic calendar 2016-2017
#           </h3>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2016-2017/feb_academic_calendar_2016-2017_bsc_eb_fe.pdf?2928681610713" target="_self">
#               BSc Economics and Business, and Fiscal Economics
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2016-2017/feb_academic_calendar_2016-2017_bsc_aeo_jaar_-1.pdf?2928681527398" target="_self">
#               BSc Econometrics and Operations Research, and Actuarial Science: year 1
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2016-2017/feb_academic_calendar_2016-2017_bsc_aeo_jaar_-2_en_3.pdf?2928681571727" target="_self">
#               BSc Econometrics and Operations Research, and Actuarial Science: year 2 and 3
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2016-2017/feb_academic_calendar_2016-2017_msc_econometrics.pdf?2928681648433" target="_self">
#               MSc Econometrics
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2016-2017/feb_academic_calendar_2016-2017_all_msc_beh_ectrics.pdf?2928681488071" target="_self">
#               Other Master's programmes
#              </a>
#             </li>
#            </ul>
#           </div>
#           <h3>
#            Academic calendar 2015-2016
#           </h3>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2015-2016/herzien---terminologie-vakaanmelding-feb_academic_calendar_2015-2016_bsc_eb_fe-2.pdf?2896728023925" target="_self">
#               BSc Economics and Business, and Fiscal Economics
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2015-2016/feb_academic_calendar_2015-2016_bsc_aeo_jaar_-1-aangepast-19-01-2016mr.pdf?2906732087298" target="_self">
#               BSc Econometrics and Operations Research, and Actuarial Science: year 1
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2015-2016/feb_academic_calendar_2015-2016_bsc_aeo_jaar_-2_en_3-aangepast-19-01-2016mr.pdf?2906732164853" target="_self">
#               BSc Econometrics and Operations Research, and Actuarial Science: year 2 and 3
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2015-2016/feb_academic_calendar_2015-2016_msc_econometrics_aangepast_20-01-16_mr.pdf?2906732207208" target="_self">
#               MSc Econometrics
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix">
#            <ul class="linklist strong">
#             <li>
#              <a class=" icon-download" href="/binaries/content/assets/studentensites/feb/economie-en-bedrijfskunde-bachelors-en-masters/a-z-engels-sia/academic-calendar/2015-2016/feb_academic_calendar_2015-2016_all_msc_beh_ectrics_aangepast_20-01-16_mr.pdf?2906732029263" target="_self">
#               Other Master's programmes
#              </a>
#             </li>
#            </ul>
#           </div>
#           <p class="meta">
#            Published by
#            <a href="mailto:redactie-feb@uva.nl">
#             Economics and Business
#            </a>
#           </p>
#           <p class="meta">
#            12 January 2018
#           </p>
#          </div>
#         </article>
#         <aside class="four columns with-border">
#          <div class="inner-spacer ">
#           <h4>
#            Question, comment or complaint?
#           </h4>
#           <ul class="linklist">
#            <li>
#             <a href="/eco/contact/questions-comments-or-complaints/questions-comments-or-complaints.html" target="_self">
#              Let us know
#             </a>
#            </li>
#           </ul>
#          </div>
#         </aside>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container clearfix equal-height">
#     <div class="sixteen columns">
#      <div class="quicknav">
#       <h4>
#        Go to
#       </h4>
#       <nav>
#        <a href="http://m.sis.uva.nl">
#         <span class="icon-64 results">
#         </span>
#         <span>
#          Study results
#         </span>
#        </a>
#        <a href="https://blackboard.uva.nl">
#         <span class="icon-64 blackboard">
#         </span>
#         <span>
#          Blackboard
#         </span>
#        </a>
#        <a href="http://student.uva.nl/en/sis">
#         <span class="icon-64 sis">
#         </span>
#         <span>
#          SIS
#         </span>
#        </a>
#        <a href="https://uvadatamonitor.uva.nl">
#         <span class="icon-64 registration-of-marks">
#         </span>
#         <span>
#          UvAdata Monitors
#         </span>
#        </a>
#        <a href="http://email.student.uva.nl">
#         <span class="icon-64 web-mail">
#         </span>
#         <span>
#          Webmail
#         </span>
#        </a>
#        <a href="http://uba.uva.nl/en/home">
#         <span class="icon-64 library">
#         </span>
#         <span>
#          Library
#         </span>
#        </a>
#        <a href="http://rooster.uva.nl">
#         <span class="icon-64 schedule">
#         </span>
#         <span>
#          Timetable
#         </span>
#        </a>
#        <a href="http://www.coursecatalogue.uva.nl">
#         <span class="icon-64 guide">
#         </span>
#         <span>
#          Course Catalogue
#         </span>
#        </a>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container equal-height clearfix">
#    <div class="sixteen columns">
#     <div class="inner-spacer" id="social-strip">
#      <span class="text-share">
#       Share this
#      </span>
#      <a class="icon icon-send_groen" href="mailto:?body=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html&amp;subject=Academic%20calendar%20-%20Students%20Economics%20and%20Business%20-%20University%20of%20Amsterdam">
#       <span class="visuallyhidden">
#        Share via email
#       </span>
#      </a>
#      <a class="icon icon-facebook_blauw" href="http://www.facebook.com/sharer.php?u=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html" target="_blank">
#       <span class="visuallyhidden">
#        Share on facebook
#       </span>
#      </a>
#      <a class="icon icon-linkedin_blauw" href="http://www.linkedin.com/shareArticle?mini=true&amp;url=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html" target="_blank">
#       <span class="visuallyhidden">
#        Share on linkedin
#       </span>
#      </a>
#      <a class="icon icon-twitter_blauw" href="http://twitter.com/share?url=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html&amp;text=Academic%20calendar%20-%20Students%20Economics%20and%20Business%20-%20University%20of%20Amsterdam" target="_blank">
#       <span class="visuallyhidden">
#        Share on twitter
#       </span>
#      </a>
#      <a class="icon icon-googleplus_oranje" href="https://plus.google.com/share?url=http%3A%2F%2Fstudent.uva.nl%2Feco%2Fcontent%2Faz%2Facademic-calendar%2Facademic-calendar.html" target="_blank">
#       <span class="visuallyhidden">
#        Share on Google+
#       </span>
#      </a>
#      <span class="text-print">
#       Print
#      </span>
#      <a class="icon icon-print_groenblauw" href="javascript:print()" title="Print this page">
#       <span class="visuallyhidden">
#        Print this page
#       </span>
#      </a>
#     </div>
#    </div>
#   </div>
#   <footer>
#    <div class="container clearfix">
#     <div class="four columns">
#      <div class="inner-spacer">
#       <ul class="linklist">
#       </ul>
#      </div>
#     </div>
#     <div class="four columns">
#      <div class="inner-spacer">
#       <ul class="linklist">
#       </ul>
#      </div>
#     </div>
#     <div class="four columns">
#      <div class="inner-spacer">
#       <ul class="linklist">
#       </ul>
#      </div>
#     </div>
#     <div class="four columns">
#      <div class="inner-spacer">
#       <ul class="linklist">
#        <li>
#         <a class="list-icon icon-twitter_blauw" href="https://twitter.com/UvA_Student">
#          Follow UvA on Twitter
#         </a>
#        </li>
#        <li>
#         <a class="list-icon icon-facebook_blauw" href="https://www.facebook.com/UniversityofAmsterdam">
#          Follow UvA on Facebook
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="container clearfix">
#     <div class="sixteen columns" id="copyright">
#      <div class="inner-spacer">
#       <span style="margin-right: 15px;">
#        Copyright UvA 2018
#       </span>
#       <a href="http://www.uva.nl/en/home/disclaimers/disclaimer">
#        Disclaimer
#       </a>
#       <a href="http://www.uva.nl/en/home/disclaimers/cookies">
#        Cookies
#       </a>
#       <a href="http://www.uva.nl/en/home/disclaimers/privacy">
#        Privacy
#       </a>
#       <span class="toggle-mobile">
#        <span class="show-mobile">
#         Mobile view
#        </span>
#        <span class="show-desktop">
#         Desktop view
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div id="cookie-bar">
#    <div class="container clearfix">
#     <div class="columns eight">
#      <div class="inner-spacer">
#       The websites of the UvA make use of cookies.
#      </div>
#     </div>
#     <div class="columns four">
#      <div class="inner-spacer">
#       <a class="close" href="#">
#        Hide this message
#       </a>
#      </div>
#     </div>
#     <div class="columns four">
#      <div class="inner-spacer">
#       <a class="right-align" href="http://www.uva.nl/en/home/disclaimers/cookies">
#        More information
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--[if lt IE 7 ]>
# <script src="//ajax.googleapis.com/ajax/libs/chrome-frame/1/CFInstall.min.js"></script>
# <script>window.attachEvent('onload',function(){CFInstall.check({mode:'overlay'})})</script>
# <![endif]-->
#  </body>
# </html>
# /Users/Iris/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/Iris/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# All the faculties that we have. (Shared data included)
faculties = {
    'fdr': {
        'full': 'Faculteit der Rechtsgeleerdheid',
        'short': 'FdR',
        'studies': {}
    },
    'feb': {
        'full': 'Faculteit Economie en Bedrijfskunde',
        'short': 'FEB',
    }, 
    'fdg': {
        'full': 'Faculteit der Geneeskunde',
        'short': 'FdG',
        'studies': {}
    },
    'shared': {
        'full': 'Gedeelde content',
        'short': 'Gedeeld',
        'studies': {}
    },
    'fgw': {
        'full': 'Faculteit der Geesteswetenschappen',
        'short': 'FGw',
        'studies': {}
    },
    'fmg': {
        'full': 'Faculteit der Maatschappij- en Gedragswetenschappen',
        'short': 'FMG',
        'studies': {}
    },
    'fnwi': {
        'full': 'Faculteit der Natuurwetenschappen, Wiskunde en Informatica',
        'short': 'FNWI',
        'studies': {}
    }
}

# %%
# specify the url for faculteit economie en bedrijfskunde
feb_url = "http://student.uva.nl/opleidingen/opleidingenlijst.html?t=feb"

# specify the url for faculteit der rechtsgeleerdheid
fdr_url = "http://student.uva.nl/opleidingen/opleidingenlijst.html?t=fdr"

# specify the url for faculteit der geesteswetenschappen
fgw_url = "http://student.uva.nl/opleidingen/opleidingenlijst.html?t=fgw"

# specify the url for faculteit der geneeskunde
fdg_url = "http://student.uva.nl/opleidingen/opleidingenlijst.html?t=medicine"

# specify the url for faculteit maatschappij en gedragswetenschappen
fmg_url = "http://student.uva.nl/opleidingen/opleidingenlijst.html?t=fmg"

# specify the url for faculteit natuurwetenschappen, wiskunde en informatica
fnwi_url = "http://student.uva.nl/opleidingen/opleidingenlijst.html?t=fnwi"

# specify the url for faculteit tandheelkunde
tand_url = "http://student.uva.nl/opleidingen/opleidingenlijst.html?t=dentistry"
# Out:
# /Users/Iris/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/Iris/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# alle studies van faculteit economie en bedrijfskunde
feb_links = get_links(read_in_page(feb_url))
feb_az = []
for link in feb_links:
    feb_az.append(link + "/az")

# alle studies van faculteit der rechtsgeleerdheid
fdr_links = get_links(read_in_page(fdr_url))
fdr_az = []
for link in fdr_links:
    fdr_az.append(link + "/az")
    
# alle studies van faculteit der geesteswetenschappen
fgw_links = get_links(read_in_page(fgw_url))
fgw_az = []
for link in fgw_links:
    fgw_az.append(link + "/az")
    
# alle studies van faculteit der geneeskunde
fdg_links = get_links(read_in_page(fdg_url))
fdg_az = []
for link in fdg_links:
    fdg_az.append(link + "/az")
    
# alle studies van faculteit maatschappij en gedragswetenschappen
fmg_links = get_links(read_in_page(fmg_url))
fmg_az = []
for link in fmg_links:
    fmg_az.append(link + "/az")
    
# alle studies van faculteit natuurwetenschappen, wiskunde en informatica
fnwi_links = get_links(read_in_page(fnwi_url))
fnwi_az = []
for link in fnwi_links:
    fnwi_az.append(link + "/az")
    
# alle studies van faculteit tandheelkunde
tand_links = get_links(read_in_page(tand_url))
tand_az = []
for link in tand_links:
    tand_az.append(link + "/az")
# Out:
# /Users/Iris/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/Iris/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# print all links to the AZ pages of each faculty
print("A-Z url for feb:", feb_az) 
print("A-Z url for fdr:", fdr_az) 
print("A-Z url for fgw:", fgw_az) 
print("A-Z url for fdg:", fdg_az) 
print("A-Z url for fmg:", fmg_az) 
print("A-Z url for fnwi:", fnwi_az) 
print("A-Z url for tand:", tand_az)
# Out:
# A-Z url for feb: ['http://www.student.uva.nl/eco/az', 'http://www.student.uva.nl/eco/az', 'http://www.student.uva.nl/ecb/az', 'http://student.uva.nl/eco/az', 'http://www.student.uva.nl/eco/az', 'http://www.student.uva.nl/eco/az', 'http://www.student.uva.nl/eco/az', 'http://www.student.uva.nl/ecb/az', 'http://www.student.uva.nl/eco/az', 'http://www.student.uva.nl/eco/az', 'http://student.uva.nl/eco/az', 'http://www.student.uva.nl/ecb/az', 'http://www.student.uva.nl/eco/az', 'http://www.student.uva.nl/ecb/az', 'http://www.student.uva.nl/ecb/az', 'http://www.student.uva.nl/pple/az']
# A-Z url for fdr: ['https://student.uva.nl/law//az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'http://www.student.uva.nl/rechten/az', 'https://student.uva.nl/rechten//az', 'https:/student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'http://www.student.uva.nl/rechten/az', 'https:/student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'http://www.student.uva.nl/pple/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten/az', 'https://student.uva.nl/rechten//az']
# A-Z url for fgw: ['http://www.student.uva.nl/ara/az', 'http://student.uva.nl/march/az', 'http://www.student.uva.nl/marc/az', 'http://student.uva.nl/march/az', 'http://student.uva.nl/march/az', 'http://www.student.uva.nl/arc/az', 'http://student.uva.nl/mac/az', 'http://student.uva.nl/mac/az', 'http://student.uva.nl/mac/az', 'http://student.uva.nl/mac/az', 'http://student.uva.nl/mac/az', 'http://student.uva.nl/mindra/az', 'http://student.uva.nl/mac/az', 'http://student.uva.nl/mac/az', 'http://student.uva.nl/mbed/az', 'http://student.uva.nl/mcac/az', 'http://student.uva.nl/mcac/az', 'http://student.uva.nl/mcac/az', 'http://student.uva.nl/bclc/az', 'http://www.student.uva.nl/mtec/az', 'http://www.student.uva.nl/mlog/az', 'http://www.student.uva.nl/mdas/az', 'http://www.student.uva.nl/mcons/az', 'http://www.student.uva.nl/acw/az', 'http://www.student.uva.nl/dui/az', 'http://www.student.uva.nl/eng/az', 'http://student.uva.nl/elac/az', 'http://www.student.uva.nl/bes/az', 'http://student.uva.nl/mes/az', 'http://student.uva.nl/mes/az', 'http://student.uva.nl/mes/az', 'http://student.uva.nl/mes/az', 'http://www.student.uva.nl/eur/az', 'http://student.uva.nl/mfi/az', 'http://student.uva.nl/mfi/az', 'http://www.student.uva.nl/fra/az', 'http://www.student.uva.nl/ges/az', 'http://student.uva.nl/mge/az', 'http://student.uva.nl/mge/az', 'http://student.uva.nl/mge/az', 'http://student.uva.nl/mge/az', 'http://student.uva.nl/mge/az', 'http://student.uva.nl/mge/az', 'http://student.uva.nl/mge/az', 'http://www.student.uva.nl/glt/az', 'http://www.student.uva.nl/heb/az', 'http://www.student.uva.nl/mers/az', 'http://www.student.uva.nl/mers/az', 'http://www.student.uva.nl/mers/az', 'http://www.student.uva.nl/mers/az', 'http://www.student.uva.nl/mpap/az', 'http://student.uva.nl/mhis/az', 'http://student.uva.nl/mhis/az', 'http://www.student.uva.nl/ita/az', 'http://student.uva.nl/mkc/az', 'http://www.student.uva.nl/mdra/az', 'http://student.uva.nl/mkc/az', 'http://student.uva.nl/mkc/az', 'http://www.student.uva.nl/kun/az', 'http://www.student.uva.nl/lat/az', 'http://student.uva.nl/blin/az', 'http://student.uva.nl/mlin/az', 'http://student.uva.nl/mlin/az', 'http://student.uva.nl/mlin/az', 'http://student.uva.nl/mlin/az', 'http://student.uva.nl/blin/az', 'http://student.uva.nl/mlit/az', 'http://student.uva.nl/mlit/az', 'http://student.uva.nl/mlit/az', 'http://student.uva.nl/lca/az', 'http://student.uva.nl/mlit/az', 'http://student.uva.nl/mlit/az', 'http://www.student.uva.nl/lit/az', 'http://student.uva.nl/mai/az', 'http://www.student.uva.nl/mc/az', 'http://www.student.uva.nl/ifw/az', 'http://student.uva.nl/mmst/az', 'http://student.uva.nl/mmst/az', 'http://www.student.uva.nl/mjem/az', 'http://student.uva.nl/mmst/az', 'http://student.uva.nl/mmst/az', 'http://www.student.uva.nl/mara/az', 'http://student.uva.nl/mheb/az', 'http://www.student.uva.nl/muz/az', 'http://www.student.uva.nl/ned/az', 'http://www.student.uva.nl/tlc/az', 'http://student.uva.nl/mne/az', 'http://student.uva.nl/mne/az', 'http://www.student.uva.nl/mred/az', 'http://www.student.uva.nl/ngr/az', 'http://student.uva.nl/bohw/az', 'http://student.uva.nl/mphi/az', 'http://student.uva.nl/mphi/az', 'http://www.student.uva.nl/rel/az', 'http://www.student.uva.nl/sca/az', 'http://www.student.uva.nl/sla/az', 'http://www.student.uva.nl/spa/az', 'http://www.student.uva.nl/atw/az', 'http://www.student.uva.nl/ngt/az', 'http://www.student.uva.nl/mntt/az', 'http://www.student.uva.nl/mtwv/az', 'http://www.student.uva.nl/thw/az', 'http://student.uva.nl/mtr/az', 'http://student.uva.nl/mtr/az', 'http://student.uva.nl/mtrs/az', 'http://student.uva.nl/mtrs/az', 'http://student.uva.nl/mtrs/az', 'http://www.student.uva.nl/wys/az']
# A-Z url for fdg: ['http://student.uva.nl/gnk/az', 'http://student.uva.nl/mgnk/az', 'http://student.uva.nl/mmi/az', 'http://student.uva.nl/mi/az']
# A-Z url for fmg: ['http://www.student.uva.nl/asw/az', 'http://www.student.uva.nl/ess/az', 'http://www.student.uva.nl/rmcde/az', 'http://www.student.uva.nl/bcw/az', 'http://student.uva.nl/cs/az', 'http://www.student.uva.nl/mcs/az', 'http://student.uva.nl/mcs/az', 'http://www.student.uva.nl/mcrg/az', 'http://www.student.uva.nl/mcas/az', 'http://www.student.uva.nl/mcsa/az', 'http://www.student.uva.nl/ca/az', 'http://www.student.uva.nl/mhg/az', 'http://www.student.uva.nl/ilo/az', 'http://www.student.uva.nl/mids/az', 'http://www.student.uva.nl/rmids/az', 'http://www.student.uva.nl/mmas/az', 'http://www.student.uva.nl/mow/az', 'http://www.student.uva.nl/pow/az', 'http://www.student.uva.nl/mpw/az', 'http://www.student.uva.nl/polsc/az', 'http://www.student.uva.nl/mpol/az', 'http://www.student.uva.nl/pol/az', 'http://www.student.uva.nl/mpol/az', 'http://www.student.uva.nl/pple/az', 'http://www.student.uva.nl/psy/az', 'http://www.student.uva.nl/rmp/az', 'http://www.student.uva.nl/rmss/az', 'http://www.student.uva.nl/sgpl/az', 'http://www.student.uva.nl/soc/az', 'http://www.student.uva.nl/bsoc/az', 'http://www.student.uva.nl/msoc/az', 'http://www.student.uva.nl/upva/az', 'http://www.student.uva.nl/murp/az', 'http://www.student.uva.nl/rmus/az']
# A-Z url for fnwi: ['http://www.student.uva.nl/ai/az', 'http://www.student.uva.nl/phys-astro/az', 'http://www.student.uva.nl/bg/az', 'http://www.student.uva.nl/bs/az', 'http://www.student.uva.nl/bio/az', 'http://www.student.uva.nl/bmed/az', 'http://www.student.uva.nl/bw/az', 'http://www.student.uva.nl/bcs/az', 'http://www.student.uva.nl/chem/az', 'http://www.student.uva.nl/cls/az', 'http://www.student.uva.nl/es/az', 'http://www.student.uva.nl/fs/az', 'http://www.student.uva.nl/fps/az', 'http://www.student.uva.nl/inc/az', 'http://www.student.uva.nl/ifk/az', 'http://www.student.uva.nl/is/az', 'http://www.student.uva.nl/ki/az', 'http://www.student.uva.nl/ls/az', 'http://www.student.uva.nl/log/az', 'http://www.student.uva.nl/mph/az', 'http://www.student.uva.nl/math/az', 'http://www.student.uva.nl/nsk/az', 'http://www.student.uva.nl/phys-astro/az', 'http://www.student.uva.nl/phys-astro/az', 'http://www.student.uva.nl/pb/az', 'http://www.student.uva.nl/sck/az', 'http://www.student.uva.nl/se/az', 'http://www.student.uva.nl/sfm/az', 'http://www.student.uva.nl/sne/az', 'http://www.student.uva.nl/wis/az']
# A-Z url for tand: ['http://student.uva.nl/opleidingen/tandheelkunde/az', 'http://student.uva.nl/opleidingen/tandheelkunde/az']
